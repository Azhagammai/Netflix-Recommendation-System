# %%
# !pip install pandas
# Out:
# ...
#   Using cached numpy-2.4.1-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.7 MB 2.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.0/9.7 MB 2.5 MB/s eta 0:00:04
#    ------ --------------------------------- 1.6/9.7 MB 2.1 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.7 MB 2.3 MB/s eta 0:00:04
#    --------- ------------------------------ 2.4/9.7 MB 2.0 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.7 MB 1.9 MB/s eta 0:00:04
#    ----------- ---------------------------- 2.9/9.7 MB 1.8 MB/s eta 0:00:04
#    ------------ --------------------------- 3.1/9.7 MB 1.7 MB/s eta 0:00:04
#    -------------- ------------------------- 3.4/9.7 MB 1.7 MB/s eta 0:00:04
# ...

# %%
import pandas as pd

df = pd.read_csv("../data/raw/netflix_movies_detailed_up_to_2025.csv")

df.head()
# Out:
#    show_id   type                                         title  \
# 0    10192  Movie                           Shrek Forever After
# 1    27205  Movie                                     Inception
# 2    12444  Movie  Harry Potter and the Deathly Hallows: Part 1
# 3    38757  Movie                                       Tangled
# 4    10191  Movie                      How to Train Your Dragon
#
#                       director  \
# 0                Mike Mitchell
# 1            Christopher Nolan
# 2                  David Yates
# 3   Byron Howard, Nathan Greno
# 4  Chris Sanders, Dean DeBlois
#
#                                                 cast  \
# 0  Mike Myers, Eddie Murphy, Cameron Diaz, Antoni...
# 1  Leonardo DiCaprio, Joseph Gordon-Levitt, Ken W...
# 2  Daniel Radcliffe, Emma Watson, Rupert Grint, T...
# 3  Mandy Moore, Zachary Levi, Donna Murphy, Ron P...
# 4  Jay Baruchel, Gerard Butler, Craig Ferguson, A...
#
# ...

# %%
df.shape
# Out:
# (16000, 18)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Data columns (total 18 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       16000 non-null  int64
#  1   type          16000 non-null  str
#  2   title         16000 non-null  str
#  3   director      15868 non-null  str
#  4   cast          15796 non-null  str
#  5   country       15534 non-null  str
#  6   date_added    16000 non-null  str
#  7   release_year  16000 non-null  int64
#  8   rating        16000 non-null  float64
#  9   duration      0 non-null      float64
#  10  genres        15893 non-null  str
#  11  language      16000 non-null  str
#  12  description   15868 non-null  str
#  13  popularity    16000 non-null  float64
#  14  vote_count    16000 non-null  int64
#  15  vote_average  16000 non-null  float64
#  16  budget        16000 non-null  int64
#  17  revenue       16000 non-null  int64
# dtypes: float64(4), int64(5), str(9)
# ...

# %%
df.isnull().sum()
# Out:
# show_id             0
# type                0
# title               0
# director          132
# cast              204
# country           466
# date_added          0
# release_year        0
# rating              0
# duration        16000
# genres            107
# language            0
# description       132
# popularity          0
# vote_count          0
# vote_average        0
# budget              0
# revenue             0
# dtype: int64

# %%
# Drop fully null column
df = df.drop(columns=["duration"])

# %%
df = df[["title", "genres", "description", "vote_average", "popularity"]]

df = df.dropna()
df = df.drop_duplicates()

df.shape
# Out:
# (15778, 5)

# %%
df.dropna()
# Out:
#                                               title  \
# 0                               Shrek Forever After
# 1                                         Inception
# 2      Harry Potter and the Deathly Hallows: Part 1
# 3                                           Tangled
# 4                          How to Train Your Dragon
# ...                                             ...
# 15990                            Blood and Stuffing
# 15991                             To a Land Unknown
# 15996                                 Man and Woman
# 15997              Night of the Dead Sorority Babes
# 15999                                Portal to Hell
#
#                                               genres  \
# 0      Comedy, Adventure, Fantasy, Animation, Family
# 1                 Action, Science Fiction, Adventure
# 2                                 Adventure, Fantasy
# 3                       Animation, Family, Adventure
# 4              Fantasy, Adventure, Animation, Family
# ...

# %%
import pandas as pd
df = pd.read_csv("../data/processed/netflix_processed.csv")
# Split genres into individual values
all_genres = df["genres"].str.split(",").explode()

# Remove extra spaces
all_genres = all_genres.str.strip()

# Get unique genres
unique_genres = sorted(all_genres.unique())

unique_genres
# Out:
# ['action',
#  'action adventure',
#  'action adventure animation',
#  'action adventure animation comedy family',
#  'action adventure animation drama',
#  'action adventure animation drama family fantasy',
#  'action adventure animation family',
#  'action adventure animation family comedy',
#  'action adventure animation family comedy tv movie',
#  'action adventure animation fantasy',
#  'action adventure animation history',
#  'action adventure animation horror',
#  'action adventure animation science fiction drama',
#  'action adventure animation science fiction fantasy',
#  'action adventure comedy',
#  'action adventure comedy animation',
#  'action adventure comedy crime',
#  'action adventure comedy crime thriller',
#  'action adventure comedy drama',
#  'action adventure comedy family',
#  'action adventure comedy family fantasy',
#  'action adventure comedy family fantasy history',
#  'action adventure comedy family science fiction',
# ...

# %%
import pandas as pd

movies = pd.read_csv("../data/processed/netflix_processed.csv")

movies['title'].head(20)
# Out:
# 0                                   Shrek Forever After
# 1                                             Inception
# 2          Harry Potter and the Deathly Hallows: Part 1
# 3                                               Tangled
# 4                              How to Train Your Dragon
# 5                                        Shutter Island
# 6                                        The Karate Kid
# 7                                            Iron Man 2
# 8                                             Grown Ups
# 9                                          Room in Rome
# 10                                        Despicable Me
# 11                                          Toy Story 3
# 12                           The Twilight Saga: Eclipse
# 13                                  Alice in Wonderland
# 14                                       A Serbian Film
# 15                           Undisputed III: Redemption
# 16                                   The Social Network
# ...
